# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\geeth\Downloads\employees_practice_dataset.csv")
print(df)
# Out:
#      EmployeeID    Name Age Department       City   Salary
# 0          1001   Helen  28    Support    Kolkata  31639.0
# 1          1002  Victor  35    Support     Mumbai  39144.0
# 2          1003     Bob  55  Marketing       Pune  35697.0
# 3          1004   Queen  22         HR  Bengaluru  36140.0
# 4          1005   Helen  22         HR       Pune  66781.0
# ..          ...     ...  ..        ...        ...      ...
# 98         1099     Tom  48    Support  Hyderabad  34585.0
# 99         1100   Queen  41         IT    Kolkata  73475.0
# 100        1005   Helen  22         HR       Pune  66781.0
# 101        1020   Grace  41    Finance     Mumbai  56290.0
# 102        1040   Oscar  40    Support  Hyderabad  56148.0
#
# [103 rows x 6 columns]

# %%
print(df.isnull().sum().sum())
# Out:
# 9

# %%
print(df.isnull().sum())
# Out:
# EmployeeID    0
# Name          0
# Age           5
# Department    0
# City          0
# Salary        4
# dtype: int64

# %%
print(df.loc[(df["Salary"]<0)])
# Out:
#     EmployeeID   Name Age Department   City   Salary
# 44        1045  Grace  53    Finance  Kochi -12000.0

# %%
print(df.duplicated().sum())
# Out:
# 3

# %%
print(df.iloc[0])
# Out:
# EmployeeID       1001
# Name            Helen
# Age                28
# Department    Support
# City          Kolkata
# Salary        31639.0
# Name: 0, dtype: object

# %%
print(df.loc[9,"Salary"])
# Out:
# 82895.0

# %%
print(df.loc[(df["Salary"]>70000)])
# Out:
#     EmployeeID     Name     Age Department       City   Salary
# 6         1007      Ian      31      Sales  Hyderabad  75753.0
# 9         1010     Ryan      37         IT      Kochi  82895.0
# 12        1013    Helen      35    Finance     Mumbai  80663.0
# 15        1016      Tom      38    Support     Mumbai  75994.0
# 18        1019      Bob      41         IT  Bengaluru  85237.0
# 25        1026      Tom      31    Support       Pune  81909.0
# 28        1029    David      55    Finance  Hyderabad  79209.0
# 31        1032      Eva      40    Support  Bengaluru  85159.0
# 32        1033      Tom      44         HR      Delhi  79971.0
# 36        1037   Victor      55         HR    Chennai  80189.0
# 43        1044  Charlie      25         IT  Hyderabad  89337.0
# 46        1047    David      51      Sales  Bengaluru  82920.0
# 47        1048     Nina      27      Sales  Hyderabad  73187.0
# 55        1056    Frank      34      Sales      Delhi  86665.0
# ...

# %%
print(df.loc[(df["Salary"]>=40000)&(df["Salary"]<=60000)])
# Out:
#      EmployeeID     Name  Age Department       City   Salary
# 7          1008  Charlie   30    Finance     Mumbai  44110.0
# 10         1011      Uma   28         IT    Kolkata  54807.0
# 13         1014      Uma   27    Finance      Kochi  54911.0
# 14         1015    Grace   44    Finance  Hyderabad  40659.0
# 17         1018   Victor   50    Finance     Chenai  54867.0
# 19         1020    Grace   41    Finance     Mumbai  56290.0
# 20         1021     Maya   41    Support      Kochi  43934.0
# 23         1024    Queen   46         HR    Chennai  53723.0
# 26         1027    Queen   -4      Sales      Kochi  55216.0
# 29         1030    Alice   39         HR      Kochi  58492.0
# 34         1035   Sophia   40         IT  Bengaluru  45692.0
# 38         1039    Wendy   48  Marketing  Bengaluru  43880.0
# 39         1040    Oscar   40    Support  Hyderabad  56148.0
# 40         1041    Helen   54         IT  Bengaluru  59588.0
# ...

# %%
print(df.loc[(df["Department"]=="HR")&(df["Salary"]>50000)])
# Out:
#      EmployeeID    Name Age Department       City   Salary
# 4          1005   Helen  22         HR       Pune  66781.0
# 11         1012     Bob  44         HR     Mumbai  67837.0
# 23         1024   Queen  46         HR    Chennai  53723.0
# 29         1030   Alice  39         HR      Kochi  58492.0
# 30         1031     Uma  37         HR     Mumbai  62806.0
# 32         1033     Tom  44         HR      Delhi  79971.0
# 36         1037  Victor  55         HR    Chennai  80189.0
# 37         1038   Queen  51         HR    Kolkata  66031.0
# 66         1067   Oscar  37         HR    Kolkata  55938.0
# 74         1075   Grace  39         HR  Hyderabad  69638.0
# 77         1078   Frank  21         HR    Kolkata  51859.0
# 85         1086   Alice  31         HR       Pune  82421.0
# 90         1091   Karen  22         HR       Pune  73255.0
# 100        1005   Helen  22         HR       Pune  66781.0

# %%
print(df.loc[4])
# Out:
# EmployeeID       1005
# Name            Helen
# Age                22
# Department         HR
# City             Pune
# Salary        66781.0
# Name: 4, dtype: object

# %%
print(df.iloc[20:31])
# Out:
#     EmployeeID    Name Age Department       City   Salary
# 20        1021    Maya  41    Support      Kochi  43934.0
# 21        1022   Helen  50    Finance    Chennai  39363.0
# 22        1023  Sophia  55    Support       Pune      NaN
# 23        1024   Queen  46         HR    Chennai  53723.0
# 24        1025     Eva  52         IT     Mumbai  35957.0
# 25        1026     Tom  31    Support       Pune  81909.0
# 26        1027   Queen  -4      Sales      Kochi  55216.0
# 27        1028  Victor  37         IT     Mumbai  66256.0
# 28        1029   David  55    Finance  Hyderabad  79209.0
# 29        1030   Alice  39         HR      Kochi  58492.0
# 30        1031     Uma  37         HR     Mumbai  62806.0

# %%
df["City"]=df["City"].replace("Mumbi","Mumbai")
print(df["City"])
# Out:
# 0        Kolkata
# 1         Mumbai
# 2           Pune
# 3      Bengaluru
# 4           Pune
#          ...
# 98     Hyderabad
# 99       Kolkata
# 100         Pune
# 101       Mumbai
# 102    Hyderabad
# Name: City, Length: 103, dtype: str

# %%
df["City"]=df["City"].replace("Chenai","Chennai")
print(df["City"])
# Out:
# 0        Kolkata
# 1         Mumbai
# 2           Pune
# 3      Bengaluru
# 4           Pune
#          ...
# 98     Hyderabad
# 99       Kolkata
# 100         Pune
# 101       Mumbai
# 102    Hyderabad
# Name: City, Length: 103, dtype: str

# %%
df["Department"]=df["Department"].replace("Finnace","Finance")
print(df["Department"])
# Out:
# 0        Support
# 1        Support
# 2      Marketing
# 3             HR
# 4             HR
#          ...
# 98       Support
# 99            IT
# 100           HR
# 101      Finance
# 102      Support
# Name: Department, Length: 103, dtype: str

# %%
df["Department"]=df["Department"].replace("it","IT")
print(df["Department"])
# Out:
# 0        Support
# 1        Support
# 2      Marketing
# 3             HR
# 4             HR
#          ...
# 98       Support
# 99            IT
# 100           HR
# 101      Finance
# 102      Support
# Name: Department, Length: 103, dtype: str

# %%
print(df.loc[(df["Department"]=="IT")|(df["Department"]=="Finance")])
# Out:
#      EmployeeID     Name     Age Department       City   Salary
# 5          1006     Yash      49    Finance      Delhi  68618.0
# 7          1008  Charlie      30    Finance     Mumbai  44110.0
# 8          1009      Tom      45    Finance     Mumbai  36338.0
# 9          1010     Ryan      37         IT      Kochi  82895.0
# 10         1011      Uma      28         IT    Kolkata  54807.0
# 12         1013    Helen      35    Finance     Mumbai  80663.0
# 13         1014      Uma      27    Finance      Kochi  54911.0
# 14         1015    Grace      44    Finance  Hyderabad  40659.0
# 17         1018   Victor      50    Finance    Chennai  54867.0
# 18         1019      Bob      41         IT  Bengaluru  85237.0
# 19         1020    Grace      41    Finance     Mumbai  56290.0
# 21         1022    Helen      50    Finance    Chennai  39363.0
# 24         1025      Eva      52         IT     Mumbai  35957.0
# 27         1028   Victor      37         IT     Mumbai  66256.0
# ...
