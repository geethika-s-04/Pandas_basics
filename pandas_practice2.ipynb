# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\geeth\Downloads\pandas_practice_eval_to_replace_dataset.csv")
print(df)
# Out:
#     EmpID Employee      Department       City  Experience  Salary  Bonus  \
# 0    1001    Frank           Sales      Kochi           7   71615   6608
# 1    1002    Priya       Marketing     Mumbai           9   64573   5867
# 2    1003      Leo       Marketing  Bengaluru           2   39497   5805
# 3    1004     Nina         Support     Bombay          10   58956   2558
# 4    1005    Priya         Support      Delhi          11   54146   2380
# 5    1006    David              IT  Bengaluru           3   66176   7618
# 6    1007      Eva              HR      Kochi           1   60798   5848
# 7    1008    Grace         Support      Kochi          13   79990  11515
# 8    1009     Sara              it  Hyderabad          14   55428   5294
# 9    1010     Sara           Sales    Chennai           6   59577  10215
# 10   1011    Priya           Sales    Chennai           1   84664   3528
# 11   1012    Alice           Sales      Delhi           9   69280  10555
# ...

# %%
df.eval("Total_Earnings = Salary + Bonus",inplace=True)
print(df.loc[df["Total_Earnings"].idxmax()])
# Out:
# EmpID                1017
# Employee             Maya
# Department        Support
# City               Mumbai
# Experience             15
# Salary              87419
# Bonus                6028
# Sales_Q1            36272
# Sales_Q2            88638
# Total_Earnings      93447
# Name: 16, dtype: object

# %%
df.eval("Net_Salary = Total_Earnings - (Total_Earnings *0.10)",inplace=True)
print(df.loc[df["Net_Salary"].idxmin()])
# Out:
# EmpID                1016
# Employee             Nina
# Department             HR
# City               Madras
# Experience             10
# Salary              30934
# Bonus                7678
# Sales_Q1            79344
# Sales_Q2            81339
# Total_Earnings      38612
# Net_Salary        34750.8
# Name: 15, dtype: object

# %%
print("Highest:__________")
print(df.loc[df["Sales_Q1"].idxmax()])
print("Lowest:__________")
print(df.loc[df["Sales_Q1"].idxmin()])
# Out:
# Highest:__________
# EmpID                  1032
# Employee               Jack
# Department        Marketing
# City              Hyderabad
# Experience                8
# Salary                67551
# Bonus                  3614
# Sales_Q1              86489
# Sales_Q2              22871
# Total_Earnings        71165
# Net_Salary          64048.5
# Name: 31, dtype: object
# Lowest:__________
# EmpID                  1002
# Employee              Priya
# Department        Marketing
# City                 Mumbai
# Experience                9
# Salary                64573
# Bonus                  5867
# Sales_Q1              15416
# Sales_Q2              16850
# Total_Earnings        70440
# Net_Salary          63396.0
# Name: 1, dtype: object

# %%
df.insert(5,"Performance",(["Excellent","Good","Average"]*14)
[:40])
print(df)
# Out:
#     EmpID Employee      Department       City  Experience Performance  Salary  \
# 0    1001    Frank           Sales      Kochi           7   Excellent   71615
# 1    1002    Priya       Marketing     Mumbai           9        Good   64573
# 2    1003      Leo       Marketing  Bengaluru           2     Average   39497
# 3    1004     Nina         Support     Bombay          10   Excellent   58956
# 4    1005    Priya         Support      Delhi          11        Good   54146
# 5    1006    David              IT  Bengaluru           3     Average   66176
# 6    1007      Eva              HR      Kochi           1   Excellent   60798
# 7    1008    Grace         Support      Kochi          13        Good   79990
# 8    1009     Sara              it  Hyderabad          14     Average   55428
# 9    1010     Sara           Sales    Chennai           6   Excellent   59577
# 10   1011    Priya           Sales    Chennai           1        Good   84664
# ...

# %%
print(df[df["Department"].isin(["IT","Finance","Sales"])])
# Out:
#     EmpID Employee Department       City  Experience Performance  Salary  \
# 0    1001    Frank      Sales      Kochi           7   Excellent   71615
# 5    1006    David         IT  Bengaluru           3     Average   66176
# 9    1010     Sara      Sales    Chennai           6   Excellent   59577
# 10   1011    Priya      Sales    Chennai           1        Good   84664
# 11   1012    Alice      Sales      Delhi           9     Average   69280
# 12   1013      Uma    Finance  Hyderabad          10   Excellent   37386
# 13   1014    Karen    Finance  Hyderabad          15        Good   50094
# 17   1018  Charlie      Sales  Bengaluru          13     Average   78589
# 18   1019      Bob    Finance      Kochi           5   Excellent   32278
# 19   1020     Maya         IT    Chennai          11        Good   88926
# 20   1021      Bob    Finance     Mumbai          11     Average   64447
# 25   1026    David      Sales      Delhi           3        Good   31659
# ...

# %%
df.replace({"Bombay":"Mumbai","Madras":"Chennai"},inplace=True)
print(df)
# Out:
#     EmpID Employee      Department       City  Experience Performance  Salary  \
# 0    1001    Frank           Sales      Kochi           7   Excellent   71615
# 1    1002    Priya       Marketing     Mumbai           9        Good   64573
# 2    1003      Leo       Marketing  Bengaluru           2     Average   39497
# 3    1004     Nina         Support     Mumbai          10   Excellent   58956
# 4    1005    Priya         Support      Delhi          11        Good   54146
# 5    1006    David              IT  Bengaluru           3     Average   66176
# 6    1007      Eva              HR      Kochi           1   Excellent   60798
# 7    1008    Grace         Support      Kochi          13        Good   79990
# 8    1009     Sara              it  Hyderabad          14     Average   55428
# 9    1010     Sara           Sales    Chennai           6   Excellent   59577
# 10   1011    Priya           Sales    Chennai           1        Good   84664
# ...

# %%
df.replace({"Finnace":"Finance","it":"IT"},inplace=True)
print(df)
# Out:
#     EmpID Employee      Department       City  Experience Performance  Salary  \
# 0    1001    Frank           Sales      Kochi           7   Excellent   71615
# 1    1002    Priya       Marketing     Mumbai           9        Good   64573
# 2    1003      Leo       Marketing  Bengaluru           2     Average   39497
# 3    1004     Nina         Support     Mumbai          10   Excellent   58956
# 4    1005    Priya         Support      Delhi          11        Good   54146
# 5    1006    David              IT  Bengaluru           3     Average   66176
# 6    1007      Eva              HR      Kochi           1   Excellent   60798
# 7    1008    Grace         Support      Kochi          13        Good   79990
# 8    1009     Sara              IT  Hyderabad          14     Average   55428
# 9    1010     Sara           Sales    Chennai           6   Excellent   59577
# 10   1011    Priya           Sales    Chennai           1        Good   84664
# ...

# %%
print(df.query("Salary>=45000 and Salary<=70000"))
# Out:
#     EmpID Employee      Department       City  Experience Performance  Salary  \
# 1    1002    Priya       Marketing     Mumbai           9        Good   64573
# 3    1004     Nina         Support     Mumbai          10   Excellent   58956
# 4    1005    Priya         Support      Delhi          11        Good   54146
# 5    1006    David              IT  Bengaluru           3     Average   66176
# 6    1007      Eva              HR      Kochi           1   Excellent   60798
# 8    1009     Sara              IT  Hyderabad          14     Average   55428
# 9    1010     Sara           Sales    Chennai           6   Excellent   59577
# 11   1012    Alice           Sales      Delhi           9     Average   69280
# 13   1014    Karen         Finance  Hyderabad          15        Good   50094
# 20   1021      Bob         Finance     Mumbai          11     Average   64447
# 22   1023     Jack  Human Resource  Hyderabad          10        Good   48086
# ...

# %%
print(df.query("Sales_Q2 > Sales_Q1"))
# Out:
#     EmpID Employee      Department       City  Experience Performance  Salary  \
# 1    1002    Priya       Marketing     Mumbai           9        Good   64573
# 3    1004     Nina         Support     Mumbai          10   Excellent   58956
# 5    1006    David              IT  Bengaluru           3     Average   66176
# 6    1007      Eva              HR      Kochi           1   Excellent   60798
# 7    1008    Grace         Support      Kochi          13        Good   79990
# 10   1011    Priya           Sales    Chennai           1        Good   84664
# 11   1012    Alice           Sales      Delhi           9     Average   69280
# 12   1013      Uma         Finance  Hyderabad          10   Excellent   37386
# 13   1014    Karen         Finance  Hyderabad          15        Good   50094
# 15   1016     Nina              HR    Chennai          10   Excellent   30934
# 16   1017     Maya         Support     Mumbai          15        Good   87419
# ...

# %%
for column, data in df.items():
    print(column,":",data.iloc[0])
# Out:
# EmpID : 1001
# Employee : Frank
# Department : Sales
# City : Kochi
# Experience : 7
# Performance : Excellent
# Salary : 71615
# Bonus : 6608
# Sales_Q1 : 77796
# Sales_Q2 : 43313
# Total_Earnings : 78223
# Net_Salary : 70400.7

# %%
for index, row in df.iterrows():
    print(row["Employee"],row["Department"],row["Salary"])
# Out:
# Frank Sales 71615
# Priya Marketing 64573
# Leo Marketing 39497
# Nina Support 58956
# Priya Support 54146
# David IT 66176
# Eva HR 60798
# Grace Support 79990
# Sara IT 55428
# Sara Sales 59577
# Priya Sales 84664
# Alice Sales 69280
# Uma Finance 37386
# Karen Finance 50094
# Charlie HR 40478
# Nina HR 30934
# Maya Support 87419
# Charlie Sales 78589
# Bob Finance 32278
# Maya IT 88926
# Bob Finance 64447
# Leo HR 80643
# Jack Human Resource 48086
# Eva Support 68907
# Ian Support 83225
# David Sales 31659
# David Support 49924
# Priya HR 41899
# Sara IT 63087
# Oscar IT 67155
# Uma Finance 46037
# Jack Marketing 67551
# Rahul Marketing 63872
# Sara HR 83391
# Charlie Finance 37052
# Rahul Marketing 72247
# Rahul Sales 44777
# Bob HR 68627
# Helen Sales 61901
# Priya HR 77000

# %%
df.eval("Total_Sales= Sales_Q1 + Sales_Q2",inplace=True)
print(df.loc[df["Total_Sales"].idxmax()])
# Out:
# EmpID                  1016
# Employee               Nina
# Department               HR
# City                Chennai
# Experience               10
# Performance       Excellent
# Salary                30934
# Bonus                  7678
# Sales_Q1              79344
# Sales_Q2              81339
# Total_Earnings        38612
# Net_Salary          34750.8
# Total_Sales          160683
# Name: 15, dtype: object

# %%
print(df.query("City in ['Bengaluru','Kochi','Hyderabad']and Experience > 5"))
# Out:
#     EmpID Employee      Department       City  Experience Performance  Salary  \
# 0    1001    Frank           Sales      Kochi           7   Excellent   71615
# 7    1008    Grace         Support      Kochi          13        Good   79990
# 8    1009     Sara              IT  Hyderabad          14     Average   55428
# 12   1013      Uma         Finance  Hyderabad          10   Excellent   37386
# 13   1014    Karen         Finance  Hyderabad          15        Good   50094
# 14   1015  Charlie              HR  Bengaluru           6     Average   40478
# 17   1018  Charlie           Sales  Bengaluru          13     Average   78589
# 22   1023     Jack  Human Resource  Hyderabad          10        Good   48086
# 24   1025      Ian         Support  Bengaluru          13   Excellent   83225
# 28   1029     Sara              IT  Hyderabad          12        Good   63087
# 29   1030    Oscar              IT  Bengaluru          13     Average   67155
# ...

# %%
df.replace({"Bombay":"Mumbai","Madras":"Chennai"},inplace=True)
print(df["City"].unique())
# Out:
# <StringArray>
# ['Kochi', 'Mumbai', 'Bengaluru', 'Delhi', 'Hyderabad', 'Chennai']
# Length: 6, dtype: str

# %%
print(df.query("Department=='Marketing' or Department=='HR' and Salary>55000"))
# Out:
#     EmpID Employee Department       City  Experience Performance  Salary  \
# 1    1002    Priya  Marketing     Mumbai           9        Good   64573
# 2    1003      Leo  Marketing  Bengaluru           2     Average   39497
# 6    1007      Eva         HR      Kochi           1   Excellent   60798
# 21   1022      Leo         HR    Chennai          10   Excellent   80643
# 31   1032     Jack  Marketing  Hyderabad           8        Good   67551
# 32   1033    Rahul  Marketing      Kochi           6     Average   63872
# 33   1034     Sara         HR      Delhi          10   Excellent   83391
# 35   1036    Rahul  Marketing      Delhi          11     Average   72247
# 37   1038      Bob         HR    Chennai          12        Good   68627
# 39   1040    Priya         HR  Bengaluru           6   Excellent   77000
#
#     Bonus  Sales_Q1  Sales_Q2  Total_Earnings  Net_Salary  Total_Sales
# 1    5867     15416     16850           70440     63396.0        32266
# ...

# %%
grade=[]
for sal in df["Salary"]:
    if sal>70000:
        grade.append("A")
    elif sal>50000:
        grade.append("B")
    else:
        grade.append("C")
df.insert(6,"Grade",grade)
print(df)
# Out:
#     EmpID Employee      Department       City  Experience Performance Grade  \
# 0    1001    Frank           Sales      Kochi           7   Excellent     A
# 1    1002    Priya       Marketing     Mumbai           9        Good     B
# 2    1003      Leo       Marketing  Bengaluru           2     Average     C
# 3    1004     Nina         Support     Mumbai          10   Excellent     B
# 4    1005    Priya         Support      Delhi          11        Good     B
# 5    1006    David              IT  Bengaluru           3     Average     B
# 6    1007      Eva              HR      Kochi           1   Excellent     B
# 7    1008    Grace         Support      Kochi          13        Good     A
# 8    1009     Sara              IT  Hyderabad          14     Average     B
# 9    1010     Sara           Sales    Chennai           6   Excellent     B
# 10   1011    Priya           Sales    Chennai           1        Good     A
# ...

# %%
df.eval("Bonus_Percentage= Bonus / Salary * 100",inplace=True)
print(df.loc[df["Bonus_Percentage"].idxmax()])
# Out:
# EmpID                    1026
# Employee                David
# Department              Sales
# City                    Delhi
# Experience                  3
# Performance              Good
# Grade                       C
# Salary                  31659
# Bonus                    9321
# Sales_Q1                33458
# Sales_Q2                24422
# Total_Earnings          40980
# Net_Salary            36882.0
# Total_Sales             57880
# Bonus_Percentage    29.441865
# Name: 25, dtype: object

# %%
print(df.query("Department!='Support'"))
print("***************************")
print(df.loc[df["Bonus"].idxmin()])
# Out:
#     EmpID Employee      Department       City  Experience Performance Grade  \
# 0    1001    Frank           Sales      Kochi           7   Excellent     A
# 1    1002    Priya       Marketing     Mumbai           9        Good     B
# 2    1003      Leo       Marketing  Bengaluru           2     Average     C
# 5    1006    David              IT  Bengaluru           3     Average     B
# 6    1007      Eva              HR      Kochi           1   Excellent     B
# 8    1009     Sara              IT  Hyderabad          14     Average     B
# 9    1010     Sara           Sales    Chennai           6   Excellent     B
# 10   1011    Priya           Sales    Chennai           1        Good     A
# 11   1012    Alice           Sales      Delhi           9     Average     B
# 12   1013      Uma         Finance  Hyderabad          10   Excellent     C
# 13   1014    Karen         Finance  Hyderabad          15        Good     B
# ...

# %%
for column,data in df.items():
    print(column,data.count())
print("**********************")
for index,row in df.iterrows():
    print(row)
# Out:
# EmpID 40
# Employee 40
# Department 40
# City 40
# Experience 40
# Performance 40
# Grade 40
# Salary 40
# Bonus 40
# Sales_Q1 40
# Sales_Q2 40
# Total_Earnings 40
# Net_Salary 40
# Total_Sales 40
# Bonus_Percentage 40
# **********************
# EmpID                    1001
# Employee                Frank
# Department              Sales
# City                    Kochi
# Experience                  7
# Performance         Excellent
# Grade                       A
# Salary                  71615
# Bonus                    6608
# Sales_Q1                77796
# Sales_Q2                43313
# Total_Earnings          78223
# Net_Salary            70400.7
# Total_Sales            121109
# Bonus_Percentage     9.227117
# Name: 0, dtype: object
# EmpID                    1002
# Employee                Priya
# Department          Marketing
# City                   Mumbai
# Experience                  9
# Performance              Good
# Grade                       B
# ...

# %%
df=df.assign(Final_Income=df["Salary"]+df["Bonus"])
df.replace({"Mumbi":"Mumbai","Chenai":"Chennai","Bombay":"Mumbai","Madras":"Chennai","Finnace":"Finance","it":"IT"},inplace=True)
print(df.loc[df["Final_Income"].idxmax()])
# Out:
# EmpID                   1017
# Employee                Maya
# Department           Support
# City                  Mumbai
# Experience                15
# Performance             Good
# Grade                      A
# Salary                 87419
# Bonus                   6028
# Sales_Q1               36272
# Sales_Q2               88638
# Total_Earnings         93447
# Net_Salary           84102.3
# Total_Sales           124910
# Bonus_Percentage    6.895526
# Final_Income           93447
# Name: 16, dtype: object
