# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\geeth\Downloads\company_employee_analysis_dataset.csv")
print(df)
# Out:
#     EmpID Employee Department       City   Salary    Bonus    Tax  Sales_Q1  \
# 0    1001    Kevin         HR  Bengaluru  72659.0  -3418.0   2186     22337
# 1    1002      Tom         IT      Kochi  44070.0  -3772.0   2408     66838
# 2    1003  Charlie         HR      Delhi  66113.0   8910.0   1968     26226
# 3    1004      Tom         IT      Kochi  68374.0   7998.0   1812     38977
# 4    1005     Sara         HR    Chennai  57468.0   -274.0   9858     25439
# 5    1006     Sara    Support     Mumbai  36753.0      NaN  10358     34624
# 6    1007    David  Marketing  Hyderabad  34114.0  13493.0   1976     36995
# 7    1008     Sara      Sales    Chennai  60513.0  14187.0   8424     57393
# 8    1009    Helen         HR  Hyderabad  81106.0   2998.0   2341     49354
# 9    1010    Priya    Finance  Hyderabad  59414.0   4435.0  10977     19594
# 10   1011    Rahul      Sales     Mumbai  79619.0   6208.0   3490     74089
# ...

# %%
print(df.count())
# Out:
# EmpID         50
# Employee      50
# Department    50
# City          49
# Salary        49
# Bonus         49
# Tax           50
# Sales_Q1      50
# Sales_Q2      50
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# EmpID         0
# Employee      0
# Department    0
# City          1
# Salary        1
# Bonus         1
# Tax           0
# Sales_Q1      0
# Sales_Q2      0
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 3

# %%
df["Salary"]=df["Salary"].add(5000)
print(df["Salary"])
# Out:
# 0     77659.0
# 1     49070.0
# 2     71113.0
# 3     73374.0
# 4     62468.0
# 5     41753.0
# 6     39114.0
# 7     65513.0
# 8     86106.0
# 9     64414.0
# 10    84619.0
# 11    85106.0
# 12    73004.0
# 13    39259.0
# 14    36478.0
# 15    85346.0
# 16    45902.0
# 17    81294.0
# 18    44915.0
# 19    52219.0
# 20        NaN
# 21    60714.0
# 22    39079.0
# 23    74369.0
# 24    75221.0
# 25    57766.0
# 26    66483.0
# 27    83519.0
# 28    58707.0
# 29    80625.0
# 30    70492.0
# 31    87646.0
# 32    36830.0
# 33    87990.0
# 34    47891.0
# 35    87405.0
# 36    63437.0
# 37    82500.0
# 38    87854.0
# 39    43584.0
# 40    89142.0
# 41    85048.0
# 42    58185.0
# 43    44950.0
# 44    85858.0
# 45    71469.0
# 46    92883.0
# 47    68273.0
# 48    68131.0
# 49    87911.0
# Name: Salary, dtype: float64

# %%
df["Tax"]=df["Tax"].sub(500)
print(df["Tax"])
# Out:
# 0      1686
# 1      1908
# 2      1468
# 3      1312
# 4      9358
# 5      9858
# 6      1476
# 7      7924
# 8      1841
# 9     10477
# 10     2990
# 11     9888
# 12     1626
# 13     5572
# 14     6323
# 15     2619
# 16     7080
# 17     6378
# 18    11289
# 19      567
# 20     2556
# 21     7036
# 22     1603
# 23     2177
# 24     1652
# 25     6466
# 26     5609
# 27     8341
# 28     9399
# 29     8993
# 30     5901
# 31     3775
# 32     8237
# 33     6474
# 34     3848
# 35    11323
# 36     1921
# 37     3285
# 38    10520
# 39      733
# 40      958
# 41     5841
# 42    11353
# 43     8864
# 44     3323
# 45     5840
# 46     1430
# 47     9703
# 48     8891
# 49     8819
# Name: Tax, dtype: int64

# %%
df["Bonus"]=df["Bonus"].mul(2)
print(df["Bonus"])
# Out:
# 0     -6836.0
# 1     -7544.0
# 2     17820.0
# 3     15996.0
# 4      -548.0
# 5         NaN
# 6     26986.0
# 7     28374.0
# 8      5996.0
# 9      8870.0
# 10    12416.0
# 11    26574.0
# 12    19896.0
# 13    -6024.0
# 14    20256.0
# 15     8836.0
# 16    19436.0
# 17    17216.0
# 18     5200.0
# 19     8476.0
# 20    10880.0
# 21    16086.0
# 22     2490.0
# 23    -6556.0
# 24    -8330.0
# 25    29470.0
# 26    21708.0
# 27     7350.0
# 28     -394.0
# 29     7112.0
# 30    22944.0
# 31     4858.0
# 32     8310.0
# 33    12906.0
# 34    12132.0
# 35    -4444.0
# 36    11790.0
# 37      410.0
# 38     -422.0
# 39    -8598.0
# 40     3830.0
# 41    28432.0
# 42    20026.0
# 43    24308.0
# 44     -184.0
# 45    -5954.0
# 46    26718.0
# 47    19632.0
# 48    29722.0
# 49    21328.0
# Name: Bonus, dtype: float64

# %%
df["HalfYearSales"]=df["Sales_Q1"].div(2)
print(df["HalfYearSales"])
# Out:
# 0     11168.5
# 1     33419.0
# 2     13113.0
# 3     19488.5
# 4     12719.5
# 5     17312.0
# 6     18497.5
# 7     28696.5
# 8     24677.0
# 9      9797.0
# 10    37044.5
# 11    25561.5
# 12    11133.5
# 13    34205.5
# 14    16013.0
# 15    21227.5
# 16    23208.0
# 17    29932.5
# 18    20291.5
# 19    14547.0
# 20    38783.0
# 21    30829.0
# 22    18681.5
# 23     5015.0
# 24    18628.0
# 25    36073.5
# 26    10628.5
# 27    15580.0
# 28     6772.0
# 29    29032.0
# 30    19617.0
# 31    38923.5
# 32    21985.0
# 33    10278.0
# 34    36631.0
# 35    12858.0
# 36    30941.5
# 37    13325.5
# 38    36087.0
# 39    11735.0
# 40    21504.0
# 41    21997.5
# 42    38866.0
# 43     6225.5
# 44    14277.0
# 45    38970.5
# 46    21285.0
# 47     6826.0
# 48    18068.0
# 49    21230.0
# Name: HalfYearSales, dtype: float64

# %%
print(df["Bonus"].abs())
# Out:
# 0      6836.0
# 1      7544.0
# 2     17820.0
# 3     15996.0
# 4       548.0
# 5         NaN
# 6     26986.0
# 7     28374.0
# 8      5996.0
# 9      8870.0
# 10    12416.0
# 11    26574.0
# 12    19896.0
# 13     6024.0
# 14    20256.0
# 15     8836.0
# 16    19436.0
# 17    17216.0
# 18     5200.0
# 19     8476.0
# 20    10880.0
# 21    16086.0
# 22     2490.0
# 23     6556.0
# 24     8330.0
# 25    29470.0
# 26    21708.0
# 27     7350.0
# 28      394.0
# 29     7112.0
# 30    22944.0
# 31     4858.0
# 32     8310.0
# 33    12906.0
# 34    12132.0
# 35     4444.0
# 36    11790.0
# 37      410.0
# 38      422.0
# 39     8598.0
# 40     3830.0
# 41    28432.0
# 42    20026.0
# 43    24308.0
# 44      184.0
# 45     5954.0
# 46    26718.0
# 47    19632.0
# 48    29722.0
# 49    21328.0
# Name: Bonus, dtype: float64

# %%
df=df.add_prefix("Emp_")
print(df)
# Out:
#     Emp_EmpID Emp_Employee Emp_Department   Emp_City  Emp_Salary  Emp_Bonus  \
# 0        1001        Kevin             HR  Bengaluru     77659.0    -6836.0
# 1        1002          Tom             IT      Kochi     49070.0    -7544.0
# 2        1003      Charlie             HR      Delhi     71113.0    17820.0
# 3        1004          Tom             IT      Kochi     73374.0    15996.0
# 4        1005         Sara             HR    Chennai     62468.0     -548.0
# 5        1006         Sara        Support     Mumbai     41753.0        NaN
# 6        1007        David      Marketing  Hyderabad     39114.0    26986.0
# 7        1008         Sara          Sales    Chennai     65513.0    28374.0
# 8        1009        Helen             HR  Hyderabad     86106.0     5996.0
# 9        1010        Priya        Finance  Hyderabad     64414.0     8870.0
# 10       1011        Rahul          Sales     Mumbai     84619.0    12416.0
# ...

# %%
df=df.add_suffix("_2026")
print(df)
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR         Delhi
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
df=df.assign(TotalIncome=df["Emp_Salary_2026"].add(df["Emp_Bonus_2026"]))
print(df)
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR         Delhi
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
df=df.assign(NetIncome=df["Emp_Salary_2026"].add(df["Emp_Bonus_2026"]))
print(df)
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR         Delhi
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
df=df.assign(Totalsales=df["Emp_Sales_Q1_2026"].add(df["Emp_Sales_Q2_2026"]))
print(df)
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR         Delhi
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
df=df.assign(Averagesales=df["Totalsales"].div(2))
print(df)
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR         Delhi
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
print(df.at[5,"Emp_Salary_2026"])
# Out:
# 41753.0

# %%
(df.at[10,"Emp_Bonus_2026"])=12000
print(df)
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR         Delhi
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
df.at[2,"Emp_City_2026"]="Pune"
print(df.loc[2])
# Out:
# Emp_EmpID_2026               1003
# Emp_Employee_2026         Charlie
# Emp_Department_2026            HR
# Emp_City_2026                Pune
# Emp_Salary_2026           71113.0
# Emp_Bonus_2026            17820.0
# Emp_Tax_2026                 1468
# Emp_Sales_Q1_2026           26226
# Emp_Sales_Q2_2026           39260
# Emp_HalfYearSales_2026    13113.0
# TotalIncome               88933.0
# NetIncome                 88933.0
# Totalsales                  65486
# Averagesales              32743.0
# Name: 2, dtype: object

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=50, step=1), Index(['Emp_EmpID_2026', 'Emp_Employee_2026', 'Emp_Department_2026',
#        'Emp_City_2026', 'Emp_Salary_2026', 'Emp_Bonus_2026', 'Emp_Tax_2026',
#        'Emp_Sales_Q1_2026', 'Emp_Sales_Q2_2026', 'Emp_HalfYearSales_2026',
#        'TotalIncome', 'NetIncome', 'Totalsales', 'Averagesales'],
#       dtype='str')]

# %%
print(df.axes[0])
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
print(df.axes[1])
# Out:
# Index(['Emp_EmpID_2026', 'Emp_Employee_2026', 'Emp_Department_2026',
#        'Emp_City_2026', 'Emp_Salary_2026', 'Emp_Bonus_2026', 'Emp_Tax_2026',
#        'Emp_Sales_Q1_2026', 'Emp_Sales_Q2_2026', 'Emp_HalfYearSales_2026',
#        'TotalIncome', 'NetIncome', 'Totalsales', 'Averagesales'],
#       dtype='str')

# %%
print(df.drop("Emp_Bonus_2026",axis=1))
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR          Pune
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
print(df.drop(["Emp_Tax_2026","Emp_City_2026"],axis=1))
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026  Emp_Salary_2026  \
# 0             1001             Kevin                  HR          77659.0
# 1             1002               Tom                  IT          49070.0
# 2             1003           Charlie                  HR          71113.0
# 3             1004               Tom                  IT          73374.0
# 4             1005              Sara                  HR          62468.0
# 5             1006              Sara             Support          41753.0
# 6             1007             David           Marketing          39114.0
# 7             1008              Sara               Sales          65513.0
# 8             1009             Helen                  HR          86106.0
# 9             1010             Priya             Finance          64414.0
# 10            1011             Rahul               Sales          84619.0
# 11            1012               Bob             Support          85106.0
# ...

# %%
print(df.drop(4,axis=0))
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR          Pune
# 3             1004               Tom                  IT         Kochi
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# 12            1013              Lara           Marketing           NaN
# ...

# %%
print(df.drop([10,11,12],axis=0))
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR          Pune
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 13            1014             Priya             Support     Hyderabad
# 14            1015              Mike             Support       Chennai
# ...

# %%
print(df.count(axis=1))
# Out:
# 0     14
# 1     14
# 2     14
# 3     14
# 4     14
# 5     11
# 6     14
# 7     14
# 8     14
# 9     14
# 10    14
# 11    14
# 12    13
# 13    14
# 14    14
# 15    14
# 16    14
# 17    14
# 18    14
# 19    14
# 20    11
# 21    14
# 22    14
# 23    14
# 24    14
# 25    14
# 26    14
# 27    14
# 28    14
# 29    14
# 30    14
# 31    14
# 32    14
# 33    14
# 34    14
# 35    14
# 36    14
# 37    14
# 38    14
# 39    14
# 40    14
# 41    14
# 42    14
# 43    14
# 44    14
# 45    14
# 46    14
# 47    14
# 48    14
# 49    14
# dtype: int64

# %%
print(df[df["Emp_Salary_2026"].eq(50000)])
# Out:
# Empty DataFrame
# Columns: [Emp_EmpID_2026, Emp_Employee_2026, Emp_Department_2026, Emp_City_2026, Emp_Salary_2026, Emp_Bonus_2026, Emp_Tax_2026, Emp_Sales_Q1_2026, Emp_Sales_Q2_2026, Emp_HalfYearSales_2026, TotalIncome, NetIncome, Totalsales, Averagesales]
# Index: []

# %%
print(df[df["Emp_Bonus_2026"].eq(0)])
# Out:
# Empty DataFrame
# Columns: [Emp_EmpID_2026, Emp_Employee_2026, Emp_Department_2026, Emp_City_2026, Emp_Salary_2026, Emp_Bonus_2026, Emp_Tax_2026, Emp_Sales_Q1_2026, Emp_Sales_Q2_2026, Emp_HalfYearSales_2026, TotalIncome, NetIncome, Totalsales, Averagesales]
# Index: []

# %%
print(df["Emp_Sales_Q1_2026"].eq(df["Emp_Sales_Q2_2026"]))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
print(df["Emp_Salary_2026"].eq(60000))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Emp_Salary_2026, dtype: bool

# %%
df=df.assign(TotalIncome=df["Emp_Salary_2026"].add(df["Emp_Bonus_2026"]))
print(df)
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR          Pune
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
print(df[df["Emp_Bonus_2026"]<0])
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 13            1014             Priya             Support     Hyderabad
# 23            1024             Frank                  IT       Chennai
# 24            1025              Sara                  IT       Chennai
# 28            1029             Alice                  HR         Kochi
# 35            1036             Priya             Support       Chennai
# 38            1039              Emma           Marketing     Bengaluru
# 39            1040              Emma           Marketing         Kochi
# 44            1045             Frank           Marketing         Delhi
# 45            1046               Uma             Support         Delhi
#
# ...

# %%
print(df["Emp_Bonus_2026"].abs())
# Out:
# 0      6836.0
# 1      7544.0
# 2     17820.0
# 3     15996.0
# 4       548.0
# 5         NaN
# 6     26986.0
# 7     28374.0
# 8      5996.0
# 9      8870.0
# 10    12000.0
# 11    26574.0
# 12    19896.0
# 13     6024.0
# 14    20256.0
# 15     8836.0
# 16    19436.0
# 17    17216.0
# 18     5200.0
# 19     8476.0
# 20    10880.0
# 21    16086.0
# 22     2490.0
# 23     6556.0
# 24     8330.0
# 25    29470.0
# 26    21708.0
# 27     7350.0
# 28      394.0
# 29     7112.0
# 30    22944.0
# 31     4858.0
# 32     8310.0
# 33    12906.0
# 34    12132.0
# 35     4444.0
# 36    11790.0
# 37      410.0
# 38      422.0
# 39     8598.0
# 40     3830.0
# 41    28432.0
# 42    20026.0
# 43    24308.0
# 44      184.0
# 45     5954.0
# 46    26718.0
# 47    19632.0
# 48    29722.0
# 49    21328.0
# Name: Emp_Bonus_2026, dtype: float64

# %%
print(df["Emp_Sales_Q1_2026"].equals(df["Emp_Sales_Q2_2026"]))
# Out:
# False

# %%
print(df.drop(["Emp_Tax_2026","Emp_Bonus_2026"],axis=1))
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR          Pune
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
df1=df.drop(["Emp_Tax_2026","Emp_Bonus_2026"],axis=1)
print(df1)
# Out:
#     Emp_EmpID_2026 Emp_Employee_2026 Emp_Department_2026 Emp_City_2026  \
# 0             1001             Kevin                  HR     Bengaluru
# 1             1002               Tom                  IT         Kochi
# 2             1003           Charlie                  HR          Pune
# 3             1004               Tom                  IT         Kochi
# 4             1005              Sara                  HR       Chennai
# 5             1006              Sara             Support        Mumbai
# 6             1007             David           Marketing     Hyderabad
# 7             1008              Sara               Sales       Chennai
# 8             1009             Helen                  HR     Hyderabad
# 9             1010             Priya             Finance     Hyderabad
# 10            1011             Rahul               Sales        Mumbai
# 11            1012               Bob             Support         Delhi
# ...

# %%
print(df1.equals(df))
# Out:
# False

# %%
import pandas as pd
df1=pd.DataFrame()
print(df1.empty)
# Out:
# True
